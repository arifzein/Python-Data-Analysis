# %% [markdown]
# <a href="https://colab.research.google.com/github/arifzein/Python-Data-Analysis/blob/master/Essential_Statistics_for_Data_Science_A_Case_Study_using_Python%2C_Part_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports for this article
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

# Read in TN middle school dataset from GitHub
df = pd.read_csv('https://raw.githubusercontent.com/LearnDataSci/article-resources/master/Essential%20Statistics/middle_tn_schools.csv')

df.describe()
# Out:
#        school_rating         size  ...  percent_asian  percent_hispanic
# count     347.000000   347.000000  ...     347.000000        347.000000
# mean        2.968300   699.472622  ...       2.642651         11.164553
# std         1.690377   400.598636  ...       3.109629         12.030608
# min         0.000000    53.000000  ...       0.000000          0.000000
# 25%         2.000000   420.500000  ...       0.750000          3.800000
# 50%         3.000000   595.000000  ...       1.600000          6.400000
# 75%         4.000000   851.000000  ...       3.100000         13.800000
# max         5.000000  2314.000000  ...      21.100000         65.200000
#
# [8 rows x 13 columns]

# %%
df[['reduced_lunch', 'school_rating']].groupby(['school_rating']).describe()
# Out:
#               reduced_lunch                        ...
#                       count       mean        std  ...   50%    75%   max
# school_rating                                      ...
# 0.0                    43.0  83.581395   8.813498  ...  86.0  90.00  98.0
# 1.0                    40.0  74.950000  11.644191  ...  74.5  84.25  98.0
# 2.0                    44.0  64.272727  11.956051  ...  62.5  74.00  88.0
# 3.0                    56.0  50.285714  13.550866  ...  48.5  63.00  78.0
# 4.0                    86.0  41.000000  16.681092  ...  41.5  50.00  87.0
# 5.0                    78.0  21.602564  17.651268  ...  19.0  29.75  87.0
#
# [6 rows x 8 columns]

# %%
# only view these two variables
df[['reduced_lunch', 'school_rating']].corr()
# Out:
#                reduced_lunch  school_rating
# reduced_lunch       1.000000      -0.815757
# school_rating      -0.815757       1.000000

# %%
fig, ax = plt.subplots(figsize=(14,8))

ax.set_ylabel('school_rating')

# boxplot with only these two variables
_ = df[['reduced_lunch', 'school_rating']].boxplot(by='school_rating', figsize=(13,8), vert=False, sym='b.', ax=ax)

# %%
plt.figure(figsize=(14,8)) # set the size of the graph
_ = sns.regplot(data=df, x='reduced_lunch', y='school_rating')

# %%
# create tabular correlation matrix
corr = df.corr()
_, ax = plt.subplots(figsize=(13,10)) 

# graph correlation matrix
_ = sns.heatmap(corr, ax=ax,
                xticklabels=corr.columns.values,
                yticklabels=corr.columns.values,
                cmap='coolwarm')
